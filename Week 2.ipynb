# %% [markdown]
# <a href="https://colab.research.google.com/github/areeba-droid/Week2_DataPreprocessing/blob/main/Week%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# In this notebook, we'll explore of Artificial Intelligence Workflow, putting a spotlight on the crucial step of Data Preprocessing.
#
# To make things clear, we'll showcase different types of data. This will help you recognize how various datasets look, where you can find them, and the steps to bring them into your work.
#
# We'll also explore specific libraries tailored for each type of data. This way, you'll get hands-on experience with the tools designed to handle different data formats effectively.
#
# After that, it's time to get hands-on with these datasets. We'll take a closer look at their unique features, understand whether they present classification or regression challenges, and use visualization techniques to make sense of the data's patterns. This practical approach not only hones your skills in data preprocessing but also empowers you to smoothly integrate various libraries and techniques into your AI workflow.

# %% [markdown]
# # **Artificial Intelligence Workflow**

# %% [markdown]
# ![ml-engineering.jpg](data:image/jpeg;base64,...)

# %% [markdown]
#  **Three Main Steps**:
#
# 1.   Data Preprocessing
# 2.   Model Engineering
# 3.   Model Depolyment
#
# **DATA Preprocessing**
#
#
#
# *   Data Gathering/Integration
# *   Data Exploration
# *   Data Cleaning
# *   Data Transforming
#
#
# **Model Engineering**
#
# *  Model Training
# * Model Evaluation
# * Model Testing
#
#
# **Model Deployment**
#
# * Model Serving
# * Model Performance monitoring

# %% [markdown]
# # **Important Libraries**

# %% [markdown]
# **Libraries required for importing data**:
#
# * Pandas
#
#
# ```
# import pandas as pd
# ```
#
#
#
# **Libraries required for visualizing data**:
#
# * Matplotlib
# * seaborn
#
# ```
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# **Libraries required for handling specific data types:**
#
# * Numerical =>  Numpy
# * Images =>  OpenCV
# * Text =>  NLTK
# * Audio =>  Librosa
# ```
# import numpy as np
# import cv2
# import nltk
# import librosa
# ```

# %% [markdown]
# ## **Installing Libraries**
#
# If you are using Google Colab, some of the libraries are preinstalled .
#
# If you are using Anaconda, almost all the libraries will be pre installed with the package.
#
# If you have downloaded individual Jupyter notebook you will need to install all the required libraries before importing them into code.
#
# Must ensure that you have pip installed in your systems

# %%
# !python3 -m pip --version
# Out:
# pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)

# %% [markdown]
# Install the library in Python using the pip command in the command prompt (cmd)
#
# You can also install libraries directly from the jupyter notebook by placing "!" before any command.
#
#
# ```
# !pip install package_name
# ```
#
# For the purpose of this notebook, we need to install all the above mentioned libararies, make sure to install them if they are not already installed.

# %%
#!pip install pandas
#!pip install matplotlib
#!pip install seaborn
#!pip install numpy
#!pip install opencv-python
#!pip install nltk
#!pip install librosa
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (4.8.0.76)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.10/dist-packages (from opencv-python) (1.23.5)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import cv2
import nltk
import librosa

# %% [markdown]
# # **DIFFERENT TYPES OF DATA**

# %% [markdown]
# ## **Tabular Data**
#  * Categorical Labels
#  * Numerical Labels

# %% [markdown]
# ### **Iris Dataset (Categorical Labels)**

# %% [markdown]
# The Iris flower data set consists of 150 samples.
#
# **Three species of Iris:**
#
# * Iris setosa
# * Iris virginica
# * Iris versicolor
#
# **Four features were measured for each sample:**
#
# * Length of the sepals (cm)
# * Width of the sepals (cm)
# * Length of the petals (cm)
# * Width of the petals (cm)
#
# **Problem Statement:**
#
# Distinguish the flowers based on these features.
#
# *Independent variables (Features)*:
# * Length of the sepals
# * Length of the petals
# * Width of the sepals
# * Width of the petals
#
# *Dependent variables (Labels)*:
# * Species of the flower

# %% [markdown]
# **Importing Required libraries**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
#
# Download the dataset from : https://www.kaggle.com/datasets/uciml/iris
#
# Copy the path of the dataset and paste it in the command *below*

# %%
dataset_1 = pd.read_csv('/content/drive/MyDrive/IAT 360/Iris.csv')

# %% [markdown]
# Preview the dataset

# %%
dataset_1.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
dataset_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# When the data is simply analyzed, none of the 6 columns contain null values, which will be a great advantage. The "Species" column will be the target feature and except for the "Id" column, which can be ignored, the other columns are of type "float64".

# %%
dataset_1.describe(include='all')

# %% [markdown]
# In the describe method, apart from the parameters that are very useful for numerical features (mean, median, 1Q, 3Q etc.), parameters such as "unique, top, freq" that will be used for categorical features are indicated with "include=all".

# %%
dataset_1['Species'].value_counts()

# %% [markdown]
# The 3 different variables of the target feature are distributed in equal numbers.

# %%
fig,(ax1,ax2) = plt.subplots(2,2)
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.SepalLengthCm,ax=ax1[0])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.SepalWidthCm,ax=ax1[1])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.PetalWidthCm,ax=ax2[0])
sns.barplot(dataset_1,x=dataset_1.Species,y=dataset_1.PetalLengthCm,ax=ax2[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# Explore the dataset more from : https://www.kaggle.com/datasets/uciml/iris

# %% [markdown]
# ### **House Price Prediction (Numerical Labels)**

# %% [markdown]
# Consisting of 4600 entries for homes in different US cities, this dataset includes 18 different variables that describe various property details such as size and location characteristics.
#
# **Columns**
#
# * date: Date the house was sold
# * price: Sale price of the house (Prediction target)
# * bedrooms: Number of the bedrooms
# * bathrooms: Number the bathrooms
# * sqft_living: Square footage of the home
# * sqft_lot: Square footage of the lot
# * floors: Total floors (levels) in the house
# * waterfront: House which has a view to a waterfront
# * view: Number of views
# * condition: How good the condition is overall
# * sqft_above: Square footage of the house apart from basement
# * sqft_basement: Square footage of the basement
# * yr_built: Building year of the house
# * yr_renovated: Renovation year of the house
# * street: Street where the house is located
# * city: City where the house is located
# * statezip: Zip code of the region where the house is located
# * country: Country where the house is located (USA)
#
# There are 8 categorical (half nominal and half ordinal depending on the measurement level) and 9 discrete variables.
#
# Our ordinal variables, waterfront, view and and renovation year, appear numerically, but we will evaluate them in two categories, 0 and 1, depending on whether they are in the relevant house or not. Also, the condition has 5 unique values that increase from 1 to 5 based on the state of the house. And as you might guess, street, city, statezip, and country are the nominal ones.
#
# **Types of Data**
#
# * Categorical (gender, blood type, aswers of yes/no questions, satisfaction/condition level etc.)
#
# * Numerical
#     1.   Discrete (finite numbers- # of children/customer/room,physical money, time on a clock etc.)
#     2.   Continuous (infinite numbers- measurements(weight, height), time in general etc.)
#
#
# **Levels of Measurement**
#
# * Qualitative
# a. Nominal (Can not be ordered- gender, blood type, seasons)
# b. Ordinal (Takes values with an order or rank- satisfaction, condition level)
# * Quantitative
# a. Interval (Don't have a true zero- temperature, pH, IQ test etc.)
# b. Ratios (Have a true zero- temperature only in Kelvin, amount, distance, pulse etc.)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#%matplotlib inline

# %% [markdown]
# **Loading Dataset**
#
#
# Download the dataset from :https://www.kaggle.com/datasets/shree1992/housedata/data
# Copy the path of the dataset and paste it in the command *below*

# %%
dataset_2 = pd.read_csv("/content/drive/MyDrive/Tutorials/Datasets/HousePricePrediction.c

# %% [markdown]
# **Exploring Dataset**

# %%
dataset_2.head()

# %%
dataset_2.info()

# %% [markdown]
# **Handling missing values**
#
# There is no NaN value in our data set, but it would be good to check 0's or 999's for the sake of data consistency. I don't see any irrelevant max values in the describe output but there are some zeros to check.

# %%
dataset_2[dataset_2==0].count()

# %% [markdown]
# We have to deal with 49 houses that look free of cost, plus 2 houses each without a bedroom and a bathroom. Since they are few in number, we can remove these values directly from our data set.

# %%
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['price']==0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['bedrooms']==0)].index)
dataset_2 = dataset_2.drop(dataset_2[(dataset_2['bathrooms']==0)].index)

# %%
dataset_2.shape

# %% [markdown]
# We can see now 4549 samples are left after removing samples with missing data. We can further explore the data and find outliers.
#
# For further exploration see: https://www.kaggle.com/datasets/shree1992/housedata

# %% [markdown]
# ## **Text Data**

# %% [markdown]
# The data is basically a collection of tweets annotated with the emotions behind them. We have three columns tweet_id, sentiment, and content. In "content" we have the raw tweet. In "sentiment" we have the emotion behind the tweet. Refer to the starter notebook for more insights.
#
# The data has 13 different emotion 40000 records.
#
# **Problem**: Finding the emotion for each tweet, also called emotion recognition from Text.

# %% [markdown]
# Importing required Libraries

# %%
import pandas as pd
import seaborn as sns

import re
import nltk
import nltk
from nltk.corpus import stopwords

from nltk.stem.snowball import SnowballStemmer
from wordcloud import WordCloud

# %% [markdown]
# Download the dataset from: https://www.kaggle.com/datasets/pashupatigupta/emotion-detection-from-text/data
#
#
# Loading Dataset

# %%
dataset_3 = pd.read_csv('/content/drive/MyDrive/IAT 360/tweet_emotions.csv')
dataset_3.head()
# Out:
#      tweet_id   sentiment                                            content
# 0  1956967341       empty  @tiffanylue i know  i was listenin to bad habi...
# 1  1956967666     sadness  Layin n bed with a headache  ughhhh...waitin o...
# 2  1956967696     sadness                Funeral ceremony...gloomy friday...
# 3  1956967789  enthusiasm               wants to hang out with friends SOON!
# 4  1956968416     neutral  @dannycastillo We want to trade with someone w...

# %% [markdown]
# Dimensions of the data  : 40,000 samples, with 3 columns

# %%
dataset_3.shape

# %% [markdown]
# Data Cleaning and EDA

# %%
dataset_3.info()

# %%
sns.countplot(x=dataset_3['sentiment'])
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# Text Preprocessing

# %%
nltk.download('stopwords')

# %%
stop_words = stopwords.words('english')
stemmer = SnowballStemmer('english')

# %%
def clean(text):
    text = text.lower()
    text = re.sub('[^\w\s]', '', text)
    text = [word for word in text.split() if word not in stop_words]
    text = [stemmer.stem(w) for w in text]
    return text

# %%
dataset_3['text'] = dataset_3['content'].apply(lambda x: clean(x))
dataset_3['text'] = dataset_3['text'].apply(lambda x: ' '.join(x))
dataset_3.head()

# %% [markdown]
# Word Cloud

# %%
all_words = ' '.join(word for word in dataset_3['text'])


wordcloud = WordCloud(
    width = 1000,
    height = 600,
    background_color = 'skyblue',
    min_font_size = 10).generate(all_words)
plt.figure(figsize = (10, 6), facecolor = None)
plt.imshow(wordcloud)
plt.axis('off')
plt.tight_layout(pad = 0)
plt.show()

# %% [markdown]
# ## **Images Data**

# %% [markdown]
#  Download the data from : https://www.kaggle.com/datasets/saworz/human-faces-with-labels/data
#
#
# There are two folders:
# 1. **Data**
#
#       Contains images of faces
# 2. **Labels**
#
#       Contains bounding boxes (labels) for the images

# %% [markdown]
# Importing required Libraries

# %%
from pathlib import Path
import os
from os import listdir
from os.path import isfile, join
import random as random
from PIL import Image
import matplotlib.pyplot as plt
from matplotlib import patches as mpatches

# %% [markdown]
# Get Data from folders

# %%
data_path= "/content/drive/MyDrive/IAT 360/Data/Data"
images_path = "/content/drive/MyDrive/IAT 360/Data/Data/Images"
annotations_path="/content/drive/MyDrive/IAT 360/Data/Data/Labels"

# %% [markdown]
# Directory Exploration

# %%
def walk_through_dir(dir_path: Path) -> None:
    """Prints dir_path content"""
    for dirpath, dirnames, filenames in os.walk(dir_path):
        print(f"There are {len(dirnames)} folders and {len(filenames)} files in '{dirpath}' folder ")


walk_through_dir(data_path)
# Out:
# There are 2 folders and 0 files in '/content/drive/MyDrive/IAT 360/Data/Data' folder
# There are 0 folders and 791 files in '/content/drive/MyDrive/IAT 360/Data/Data/Images' folder
# There are 0 folders and 791 files in '/content/drive/MyDrive/IAT 360/Data/Data/Labels' folder

# %% [markdown]
# Print some random images and draw bounding boxes to see if they are correct

# %%
def print_random_images(photos: list, n: int = 5, seed=None):
    if n > 10:
        n=10
    if seed:
        rnd.seed(seed)

    for im in range(n):
        random_photo = random.choice(photos)
        random_photo_path = str(images_path) + '/' + str(random_photo)

        with Image.open(random_photo_path) as fd:
            fig, ax = plt.subplots()
            ax.imshow(fd)
            ax.axis(False)
            image_width, image_height = fd.size

        file=random_photo[:random_photo.index(".")] + '.txt'
        annotation_file = annotations_path+"/"+ file
        with open(annotation_file) as f:
            label = f.read()

        labels = label.split(" ")
        labels[4] = labels[4][:-1]
        labels = list(map(float, labels))

        x1, y1, width, height=labels[1:]
        bbox_x = x1*image_width-image_width*width/2
        bbox_y = y1*image_height-image_height*height/2
        bbox_width=width*image_width
        bbox_height=height*image_height

        mpatch=mpatches.Rectangle((bbox_x, bbox_y), bbox_width, bbox_height, linewidth=1, edgecolor='b', facecolor="none", lw=2)
        ax.add_patch(mpatch)
        rx, ry = mpatch.get_xy()
        ax.annotate('face', (rx, ry-2), color='blue', weight='bold', fontsize=12, ha='left', va='baseline')

photos_list = [f for f in listdir(images_path) if isfile(join(images_path, f))]

print_random_images(photos_list)

# %% [markdown]
# ## **Audio Data**

# %% [markdown]
# **Files**
# This portion of the RAVDESS contains 1440 files: 60 trials per actor x 24 actors = 1440. The RAVDESS contains 24 professional actors (12 female, 12 male), vocalizing two lexically-matched statements in a neutral North American accent. Speech emotions includes calm, happy, sad, angry, fearful, surprise, and disgust expressions. Each expression is produced at two levels of emotional intensity (normal, strong), with an additional neutral expression.
#
# **File naming convention**
#
# Each of the 1440 files has a unique filename. The filename consists of a 7-part numerical identifier (e.g., 03-01-06-01-02-01-12.wav). These identifiers define the stimulus characteristics:
#
# **Filename identifiers**
#
# * Modality (01 = full-AV, 02 = video-only, 03 = audio-only).
#
# * Vocal channel (01 = speech, 02 = song).
#
# * Emotion (01 = neutral, 02 = calm, 03 = happy, 04 = sad, 05 = angry, 06 = fearful, 07 = disgust, 08 = surprised).
#
# * Emotional intensity (01 = normal, 02 = strong). NOTE: There is no strong intensity for the 'neutral' emotion.
#
# * Statement (01 = "Kids are talking by the door", 02 = "Dogs are sitting by the door").
#
# * Repetition (01 = 1st repetition, 02 = 2nd repetition).
#
# * Actor (01 to 24. Odd numbered actors are male, even numbered actors are female).
#
# Filename example: 03-01-06-01-02-01-12.wav
#
# 1. Audio-only (03)
# 2. Speech (01)
# 3. Fearful (06)
# 4. Normal intensity (01)
# 5. Statement "dogs" (02)
# 6. 1st Repetition (01)
# 7. 12th Actor (12) Female, as the actor ID number is even.

# %% [markdown]
# Importing Libraries

# %%
#importing the required libraries

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import librosa.display
import soundfile
import os

from glob import glob

import librosa
import IPython.display as ipd

# %% [markdown]
# Download the dataset from the [audio dataset folder.](https://1sfu-my.sharepoint.com/:f:/g/personal/oyalcin_sfu_ca/ErKIxg5g4rFOlfrAZ352DW4BD1ytBiz1kZLcj5Elk9_1rQ?e=lgUQoi)
#
# ### Load the Dataset and Compute Features
# We have to understand the labelling of the RAVDESS dataset to find the ground truth emotion for each sample.
# Each file is labelled with 7 numbers delimited by a "-".
# Most of the numbers describe metadata about the audio samples such as their format (video and/or audio),
# whether the audio is a song or statement, which of two statements is being read and by which actor.
#
# The third and fourth numbers pertain to the emotional quality of each sample. The third number is in the range of 1-8 with each number representing an emotion.
# The fourth number is either 1 or 2, representing normal (1) or strong (2) emotional intensity.
#
# When you upload your own data, you should be using this convention.
#
# We're going to define a dictionary based on the third number (emotion) and assign an emotion to each number as specified by the RAVDESS dataset:

# %%
# linked the file directory to my google drive
audio_files = glob('/content/drive/MyDrive/IAT 360/Audio Data/*/*.wav')


#Playing an audio file using IPython.display
ipd.Audio(audio_files[0])
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#Emotions in the RAVDESS dataset
emotions_dict ={
  '01':'neutral',
  '02':'calm',
  '03':'happy',
  '04':'sad',
  '05':'angry',
  '06':'fearful',
  '07':'disgust',
  '08':'surprised'
}

#added another dictionary to store the different actor genders
gender_dict = {
    '01': 'male',
    '02': 'female'
}

# %% [markdown]
# Now we're going to load our data and extract the emotion names according to the list we provided above.

# %%
import os, glob

def load_data():
    X,y=[],[]
    count = 0
    for file in glob.glob("/content/drive/MyDrive/IAT 360/Audio Data/Actor_*/*.wav"):
        file_name=os.path.basename(file)
        emotion=emotions_dict[file_name.split("-")[2]]
        #getting the file name and splitting the name by '-', then getting the 6th index and splitting it again with '.' to remove the ".wav", ang getting the first part to read
        if(int(file_name.split("-")[6].split('.')[0]) % 2): #cheking of the gotten index is even or odd
          #add it to the female
          gender=gender_dict['01']
        else:
          # add it to the male
          gender=gender_dict['02']

        #features = get_features(file)
        #appending the gotten gender to the created x array
        X.append(gender)
        #appending the gotten emotion to the created y array
        y.append(emotion)
        count += 1
        # '\r' + end='' results in printing over same line
        print('\r' + f' Processed {count}/{1448} audio samples',end=' ')
        print(gender)
    # Return arrays to plug into sklearn's cross-validation algorithms
    return np.array(X), np.array(y)

# %% [markdown]
# We will not compute the feature matrix this week, but we will read the emotion labels for the entire dataset.
# We will explain why the X and Y elements are important in the upcoming weeks.

# %%
features, emotions = load_data()
# Out:
#  Processed 1/1448 audio samples female
#  Processed 2/1448 audio samples female
#  Processed 3/1448 audio samples female
#  Processed 4/1448 audio samples female
#  Processed 5/1448 audio samples female
#  Processed 6/1448 audio samples female
#  Processed 7/1448 audio samples female
#  Processed 8/1448 audio samples female
#  Processed 9/1448 audio samples female
#  Processed 10/1448 audio samples female
#  Processed 11/1448 audio samples female
#  Processed 12/1448 audio samples female
#  Processed 13/1448 audio samples female
#  Processed 14/1448 audio samples female
#  Processed 15/1448 audio samples female
#  Processed 16/1448 audio samples female
#  Processed 17/1448 audio samples female
#  Processed 18/1448 audio samples female
#  Processed 19/1448 audio samples female
#  Processed 20/1448 audio samples female
#  Processed 21/1448 audio samples female
#  Processed 22/1448 audio samples female
#  Processed 23/1448 audio samples female
#  Processed 24/1448 audio samples female
#  Processed 25/1448 audio samples female
#  Processed 26/1448 audio samples female
#  Processed 27/1448 audio samples female
#  Processed 28/1448 audio samples female
#  Processed 29/1448 audio samples female
#  Processed 30/1448 audio samples female
#  Processed 31/1448 audio samples female
#  Processed 32/1448 audio samples female
#  Processed 33/1448 audio samples female
#  Processed 34/1448 audio samples female
#  Processed 35/1448 audio samples female
#  Processed 36/1448 audio samples female
#  Processed 37/1448 audio samples female
#  Processed 38/1448 audio samples female
#  Processed 39/1448 audio samples female
#  Processed 40/1448 audio samples female
#  Processed 41/1448 audio samples female
#  Processed 42/1448 audio samples female
#  Processed 43/1448 audio samples female
#  Processed 44/1448 audio samples female
#  Processed 45/1448 audio samples female
#  Processed 46/1448 audio samples female
#  Processed 47/1448 audio samples female
#  Processed 48/1448 audio samples female
#  Processed 49/1448 audio samples female
#  Processed 50/1448 audio samples female
#  Processed 51/1448 audio samples female
#  Processed 52/1448 audio samples female
#  Processed 53/1448 audio samples female
#  Processed 54/1448 audio samples female
#  Processed 55/1448 audio samples female
#  Processed 56/1448 audio samples female
#  Processed 57/1448 audio samples female
#  Processed 58/1448 audio samples female
#  Processed 59/1448 audio samples female
#  Processed 60/1448 audio samples female
#  Processed 61/1448 audio samples male
#  Processed 62/1448 audio samples male
#  Processed 63/1448 audio samples male
#  Processed 64/1448 audio samples male
#  Processed 65/1448 audio samples male
#  Processed 66/1448 audio samples male
#  Processed 67/1448 audio samples male
#  Processed 68/1448 audio samples male
#  Processed 69/1448 audio samples male
#  Processed 70/1448 audio samples male
#  Processed 71/1448 audio samples male
#  Processed 72/1448 audio samples male
#  Processed 73/1448 audio samples male
#  Processed 74/1448 audio samples male
#  Processed 75/1448 audio samples male
#  Processed 76/1448 audio samples male
#  Processed 77/1448 audio samples male
#  Processed 78/1448 audio samples male
#  Processed 79/1448 audio samples male
#  Processed 80/1448 audio samples male
#  Processed 81/1448 audio samples male
#  Processed 82/1448 audio samples male
#  Processed 83/1448 audio samples male
#  Processed 84/1448 audio samples male
#  Processed 85/1448 audio samples male
#  Processed 86/1448 audio samples male
#  Processed 87/1448 audio samples male
#  Processed 88/1448 audio samples male
#  Processed 89/1448 audio samples male
#  Processed 90/1448 audio samples male
#  Processed 91/1448 audio samples male
#  Processed 92/1448 audio samples male
#  Processed 93/1448 audio samples male
#  Processed 94/1448 audio samples male
#  Processed 95/1448 audio samples male
#  Processed 96/1448 audio samples male
#  Processed 97/1448 audio samples male
#  Processed 98/1448 audio samples male
#  Processed 99/1448 audio samples male
#  Processed 100/1448 audio samples male
#  Processed 101/1448 audio samples male
#  Processed 102/1448 audio samples male
#  Processed 103/1448 audio samples male
#  Processed 104/1448 audio samples male
#  Processed 105/1448 audio samples male
#  Processed 106/1448 audio samples male
#  Processed 107/1448 audio samples male
#  Processed 108/1448 audio samples male
#  Processed 109/1448 audio samples male
#  Processed 110/1448 audio samples male
#  Processed 111/1448 audio samples male
#  Processed 112/1448 audio samples male
#  Processed 113/1448 audio samples male
#  Processed 114/1448 audio samples male
#  Processed 115/1448 audio samples male
#  Processed 116/1448 audio samples male
#  Processed 117/1448 audio samples male
#  Processed 118/1448 audio samples male
#  Processed 119/1448 audio samples male
#  Processed 120/1448 audio samples male
#  Processed 121/1448 audio samples male
#  Processed 122/1448 audio samples male
#  Processed 123/1448 audio samples male
#  Processed 124/1448 audio samples male
#  Processed 125/1448 audio samples male
#  Processed 126/1448 audio samples male
#  Processed 127/1448 audio samples male
#  Processed 128/1448 audio samples male
#  Processed 129/1448 audio samples male
#  Processed 130/1448 audio samples male
#  Processed 131/1448 audio samples male
#  Processed 132/1448 audio samples male
#  Processed 133/1448 audio samples male
#  Processed 134/1448 audio samples male
#  Processed 135/1448 audio samples male
#  Processed 136/1448 audio samples male
#  Processed 137/1448 audio samples male
#  Processed 138/1448 audio samples male
#  Processed 139/1448 audio samples male
#  Processed 140/1448 audio samples male
#  Processed 141/1448 audio samples male
#  Processed 142/1448 audio samples male
#  Processed 143/1448 audio samples male
#  Processed 144/1448 audio samples male
#  Processed 145/1448 audio samples male
#  Processed 146/1448 audio samples male
#  Processed 147/1448 audio samples male
#  Processed 148/1448 audio samples male
#  Processed 149/1448 audio samples male
#  Processed 150/1448 audio samples male
#  Processed 151/1448 audio samples male
#  Processed 152/1448 audio samples male
#  Processed 153/1448 audio samples male
#  Processed 154/1448 audio samples male
#  Processed 155/1448 audio samples male
#  Processed 156/1448 audio samples male
#  Processed 157/1448 audio samples male
#  Processed 158/1448 audio samples male
#  Processed 159/1448 audio samples male
#  Processed 160/1448 audio samples male
#  Processed 161/1448 audio samples male
#  Processed 162/1448 audio samples male
#  Processed 163/1448 audio samples male
#  Processed 164/1448 audio samples male
#  Processed 165/1448 audio samples male
#  Processed 166/1448 audio samples male
#  Processed 167/1448 audio samples male
#  Processed 168/1448 audio samples male
#  Processed 169/1448 audio samples male
#  Processed 170/1448 audio samples male
#  Processed 171/1448 audio samples male
#  Processed 172/1448 audio samples male
#  Processed 173/1448 audio samples male
#  Processed 174/1448 audio samples male
#  Processed 175/1448 audio samples male
#  Processed 176/1448 audio samples male
#  Processed 177/1448 audio samples male
#  Processed 178/1448 audio samples male
#  Processed 179/1448 audio samples male
#  Processed 180/1448 audio samples male
#  Processed 181/1448 audio samples female
#  Processed 182/1448 audio samples female
#  Processed 183/1448 audio samples female
#  Processed 184/1448 audio samples female
#  Processed 185/1448 audio samples female
#  Processed 186/1448 audio samples female
#  Processed 187/1448 audio samples female
#  Processed 188/1448 audio samples female
#  Processed 189/1448 audio samples female
#  Processed 190/1448 audio samples female
#  Processed 191/1448 audio samples female
#  Processed 192/1448 audio samples female
#  Processed 193/1448 audio samples female
#  Processed 194/1448 audio samples female
#  Processed 195/1448 audio samples female
#  Processed 196/1448 audio samples female
#  Processed 197/1448 audio samples female
#  Processed 198/1448 audio samples female
#  Processed 199/1448 audio samples female
#  Processed 200/1448 audio samples female
#  Processed 201/1448 audio samples female
#  Processed 202/1448 audio samples female
#  Processed 203/1448 audio samples female
#  Processed 204/1448 audio samples female
#  Processed 205/1448 audio samples female
#  Processed 206/1448 audio samples female
#  Processed 207/1448 audio samples female
#  Processed 208/1448 audio samples female
#  Processed 209/1448 audio samples female
#  Processed 210/1448 audio samples female
#  Processed 211/1448 audio samples female
#  Processed 212/1448 audio samples female
#  Processed 213/1448 audio samples female
#  Processed 214/1448 audio samples female
#  Processed 215/1448 audio samples female
#  Processed 216/1448 audio samples female
#  Processed 217/1448 audio samples female
#  Processed 218/1448 audio samples female
#  Processed 219/1448 audio samples female
#  Processed 220/1448 audio samples female
#  Processed 221/1448 audio samples female
#  Processed 222/1448 audio samples female
#  Processed 223/1448 audio samples female
#  Processed 224/1448 audio samples female
#  Processed 225/1448 audio samples female
#  Processed 226/1448 audio samples female
#  Processed 227/1448 audio samples female
#  Processed 228/1448 audio samples female
#  Processed 229/1448 audio samples female
#  Processed 230/1448 audio samples female
#  Processed 231/1448 audio samples female
#  Processed 232/1448 audio samples female
#  Processed 233/1448 audio samples female
#  Processed 234/1448 audio samples female
#  Processed 235/1448 audio samples female
#  Processed 236/1448 audio samples female
#  Processed 237/1448 audio samples female
#  Processed 238/1448 audio samples female
#  Processed 239/1448 audio samples female
#  Processed 240/1448 audio samples female
#  Processed 241/1448 audio samples female
#  Processed 242/1448 audio samples female
#  Processed 243/1448 audio samples female
#  Processed 244/1448 audio samples female
#  Processed 245/1448 audio samples female
#  Processed 246/1448 audio samples female
#  Processed 247/1448 audio samples female
#  Processed 248/1448 audio samples female
#  Processed 249/1448 audio samples female
#  Processed 250/1448 audio samples female
#  Processed 251/1448 audio samples female
#  Processed 252/1448 audio samples female
#  Processed 253/1448 audio samples female
#  Processed 254/1448 audio samples female
#  Processed 255/1448 audio samples female
#  Processed 256/1448 audio samples female
#  Processed 257/1448 audio samples female
#  Processed 258/1448 audio samples female
#  Processed 259/1448 audio samples female
#  Processed 260/1448 audio samples female
#  Processed 261/1448 audio samples female
#  Processed 262/1448 audio samples female
#  Processed 263/1448 audio samples female
#  Processed 264/1448 audio samples female
#  Processed 265/1448 audio samples female
#  Processed 266/1448 audio samples female
#  Processed 267/1448 audio samples female
#  Processed 268/1448 audio samples female
#  Processed 269/1448 audio samples female
#  Processed 270/1448 audio samples female
#  Processed 271/1448 audio samples female
#  Processed 272/1448 audio samples female
#  Processed 273/1448 audio samples female
#  Processed 274/1448 audio samples female
#  Processed 275/1448 audio samples female
#  Processed 276/1448 audio samples female
#  Processed 277/1448 audio samples female
#  Processed 278/1448 audio samples female
#  Processed 279/1448 audio samples female
#  Processed 280/1448 audio samples female
#  Processed 281/1448 audio samples female
#  Processed 282/1448 audio samples female
#  Processed 283/1448 audio samples female
#  Processed 284/1448 audio samples female
#  Processed 285/1448 audio samples female
#  Processed 286/1448 audio samples female
#  Processed 287/1448 audio samples female
#  Processed 288/1448 audio samples female
#  Processed 289/1448 audio samples female
#  Processed 290/1448 audio samples female
#  Processed 291/1448 audio samples female
#  Processed 292/1448 audio samples female
#  Processed 293/1448 audio samples female
#  Processed 294/1448 audio samples female
#  Processed 295/1448 audio samples female
#  Processed 296/1448 audio samples female
#  Processed 297/1448 audio samples female
#  Processed 298/1448 audio samples female
#  Processed 299/1448 audio samples female
#  Processed 300/1448 audio samples female
#  Processed 301/1448 audio samples male
#  Processed 302/1448 audio samples male
#  Processed 303/1448 audio samples male
#  Processed 304/1448 audio samples male
#  Processed 305/1448 audio samples male
#  Processed 306/1448 audio samples male
#  Processed 307/1448 audio samples male
#  Processed 308/1448 audio samples male
#  Processed 309/1448 audio samples male
#  Processed 310/1448 audio samples male
#  Processed 311/1448 audio samples male
#  Processed 312/1448 audio samples male
#  Processed 313/1448 audio samples male
#  Processed 314/1448 audio samples male
#  Processed 315/1448 audio samples male
#  Processed 316/1448 audio samples male
#  Processed 317/1448 audio samples male
#  Processed 318/1448 audio samples male
#  Processed 319/1448 audio samples male
#  Processed 320/1448 audio samples male
#  Processed 321/1448 audio samples male
#  Processed 322/1448 audio samples male
#  Processed 323/1448 audio samples male
#  Processed 324/1448 audio samples male
#  Processed 325/1448 audio samples male
#  Processed 326/1448 audio samples male
#  Processed 327/1448 audio samples male
#  Processed 328/1448 audio samples male
#  Processed 329/1448 audio samples male
#  Processed 330/1448 audio samples male
#  Processed 331/1448 audio samples male
#  Processed 332/1448 audio samples male
#  Processed 333/1448 audio samples male
#  Processed 334/1448 audio samples male
#  Processed 335/1448 audio samples male
#  Processed 336/1448 audio samples male
#  Processed 337/1448 audio samples male
#  Processed 338/1448 audio samples male
#  Processed 339/1448 audio samples male
#  Processed 340/1448 audio samples male
#  Processed 341/1448 audio samples male
#  Processed 342/1448 audio samples male
#  Processed 343/1448 audio samples male
#  Processed 344/1448 audio samples male
#  Processed 345/1448 audio samples male
#  Processed 346/1448 audio samples male
#  Processed 347/1448 audio samples male
#  Processed 348/1448 audio samples male
#  Processed 349/1448 audio samples male
#  Processed 350/1448 audio samples male
#  Processed 351/1448 audio samples male
#  Processed 352/1448 audio samples male
#  Processed 353/1448 audio samples male
#  Processed 354/1448 audio samples male
#  Processed 355/1448 audio samples male
#  Processed 356/1448 audio samples male
#  Processed 357/1448 audio samples male
#  Processed 358/1448 audio samples male
#  Processed 359/1448 audio samples male
#  Processed 360/1448 audio samples male
#  Processed 361/1448 audio samples male
#  Processed 362/1448 audio samples male
#  Processed 363/1448 audio samples male
#  Processed 364/1448 audio samples male
#  Processed 365/1448 audio samples male
#  Processed 366/1448 audio samples male
#  Processed 367/1448 audio samples male
#  Processed 368/1448 audio samples male
#  Processed 369/1448 audio samples male
#  Processed 370/1448 audio samples male
#  Processed 371/1448 audio samples male
#  Processed 372/1448 audio samples male
#  Processed 373/1448 audio samples male
#  Processed 374/1448 audio samples male
#  Processed 375/1448 audio samples male
#  Processed 376/1448 audio samples male
#  Processed 377/1448 audio samples male
#  Processed 378/1448 audio samples male
#  Processed 379/1448 audio samples male
#  Processed 380/1448 audio samples male
#  Processed 381/1448 audio samples male
#  Processed 382/1448 audio samples male
#  Processed 383/1448 audio samples male
#  Processed 384/1448 audio samples male
#  Processed 385/1448 audio samples male
#  Processed 386/1448 audio samples male
#  Processed 387/1448 audio samples male
#  Processed 388/1448 audio samples male
#  Processed 389/1448 audio samples male
#  Processed 390/1448 audio samples male
#  Processed 391/1448 audio samples male
#  Processed 392/1448 audio samples male
#  Processed 393/1448 audio samples male
#  Processed 394/1448 audio samples male
#  Processed 395/1448 audio samples male
#  Processed 396/1448 audio samples male
#  Processed 397/1448 audio samples male
#  Processed 398/1448 audio samples male
#  Processed 399/1448 audio samples male
#  Processed 400/1448 audio samples male
#  Processed 401/1448 audio samples male
#  Processed 402/1448 audio samples male
#  Processed 403/1448 audio samples male
#  Processed 404/1448 audio samples male
#  Processed 405/1448 audio samples male
#  Processed 406/1448 audio samples male
#  Processed 407/1448 audio samples male
#  Processed 408/1448 audio samples male
#  Processed 409/1448 audio samples male
#  Processed 410/1448 audio samples male
#  Processed 411/1448 audio samples male
#  Processed 412/1448 audio samples male
#  Processed 413/1448 audio samples male
#  Processed 414/1448 audio samples male
#  Processed 415/1448 audio samples male
#  Processed 416/1448 audio samples male
#  Processed 417/1448 audio samples male
#  Processed 418/1448 audio samples male
#  Processed 419/1448 audio samples male
#  Processed 420/1448 audio samples male
#  Processed 421/1448 audio samples female
#  Processed 422/1448 audio samples female
#  Processed 423/1448 audio samples female
#  Processed 424/1448 audio samples female
#  Processed 425/1448 audio samples female
#  Processed 426/1448 audio samples female
#  Processed 427/1448 audio samples female
#  Processed 428/1448 audio samples female
#  Processed 429/1448 audio samples female
#  Processed 430/1448 audio samples female
#  Processed 431/1448 audio samples female
#  Processed 432/1448 audio samples female
#  Processed 433/1448 audio samples female
#  Processed 434/1448 audio samples female
#  Processed 435/1448 audio samples female
#  Processed 436/1448 audio samples female
#  Processed 437/1448 audio samples female
#  Processed 438/1448 audio samples female
#  Processed 439/1448 audio samples female
#  Processed 440/1448 audio samples female
#  Processed 441/1448 audio samples female
#  Processed 442/1448 audio samples female
#  Processed 443/1448 audio samples female
#  Processed 444/1448 audio samples female
#  Processed 445/1448 audio samples female
#  Processed 446/1448 audio samples female
#  Processed 447/1448 audio samples female
#  Processed 448/1448 audio samples female
#  Processed 449/1448 audio samples female
#  Processed 450/1448 audio samples female
#  Processed 451/1448 audio samples female
#  Processed 452/1448 audio samples female
#  Processed 453/1448 audio samples female
#  Processed 454/1448 audio samples female
#  Processed 455/1448 audio samples female
#  Processed 456/1448 audio samples female
#  Processed 457/1448 audio samples female
#  Processed 458/1448 audio samples female
#  Processed 459/1448 audio samples female
#  Processed 460/1448 audio samples female
#  Processed 461/1448 audio samples female
#  Processed 462/1448 audio samples female
#  Processed 463/1448 audio samples female
#  Processed 464/1448 audio samples female
#  Processed 465/1448 audio samples female
#  Processed 466/1448 audio samples female
#  Processed 467/1448 audio samples female
#  Processed 468/1448 audio samples female
#  Processed 469/1448 audio samples female
#  Processed 470/1448 audio samples female
#  Processed 471/1448 audio samples female
#  Processed 472/1448 audio samples female
#  Processed 473/1448 audio samples female
#  Processed 474/1448 audio samples female
#  Processed 475/1448 audio samples female
#  Processed 476/1448 audio samples female
#  Processed 477/1448 audio samples female
#  Processed 478/1448 audio samples female
#  Processed 479/1448 audio samples female
#  Processed 480/1448 audio samples female
#  Processed 481/1448 audio samples female
#  Processed 482/1448 audio samples female
#  Processed 483/1448 audio samples female
#  Processed 484/1448 audio samples female
#  Processed 485/1448 audio samples female
#  Processed 486/1448 audio samples female
#  Processed 487/1448 audio samples female
#  Processed 488/1448 audio samples female
#  Processed 489/1448 audio samples female
#  Processed 490/1448 audio samples female
#  Processed 491/1448 audio samples female
#  Processed 492/1448 audio samples female
#  Processed 493/1448 audio samples female
#  Processed 494/1448 audio samples female
#  Processed 495/1448 audio samples female
#  Processed 496/1448 audio samples female
#  Processed 497/1448 audio samples female
#  Processed 498/1448 audio samples female
#  Processed 499/1448 audio samples female
#  Processed 500/1448 audio samples female
#  Processed 501/1448 audio samples female
#  Processed 502/1448 audio samples female
#  Processed 503/1448 audio samples female
#  Processed 504/1448 audio samples female
#  Processed 505/1448 audio samples female
#  Processed 506/1448 audio samples female
#  Processed 507/1448 audio samples female
#  Processed 508/1448 audio samples female
#  Processed 509/1448 audio samples female
#  Processed 510/1448 audio samples female
#  Processed 511/1448 audio samples female
#  Processed 512/1448 audio samples female
#  Processed 513/1448 audio samples female
#  Processed 514/1448 audio samples female
#  Processed 515/1448 audio samples female
#  Processed 516/1448 audio samples female
#  Processed 517/1448 audio samples female
#  Processed 518/1448 audio samples female
#  Processed 519/1448 audio samples female
#  Processed 520/1448 audio samples female
#  Processed 521/1448 audio samples female
#  Processed 522/1448 audio samples female
#  Processed 523/1448 audio samples female
#  Processed 524/1448 audio samples female
#  Processed 525/1448 audio samples female
#  Processed 526/1448 audio samples female
#  Processed 527/1448 audio samples female
#  Processed 528/1448 audio samples female
#  Processed 529/1448 audio samples female
#  Processed 530/1448 audio samples female
#  Processed 531/1448 audio samples female
#  Processed 532/1448 audio samples female
#  Processed 533/1448 audio samples female
#  Processed 534/1448 audio samples female
#  Processed 535/1448 audio samples female
#  Processed 536/1448 audio samples female
#  Processed 537/1448 audio samples female
#  Processed 538/1448 audio samples female
#  Processed 539/1448 audio samples female
#  Processed 540/1448 audio samples male
#  Processed 541/1448 audio samples male
#  Processed 542/1448 audio samples male
#  Processed 543/1448 audio samples male
#  Processed 544/1448 audio samples male
#  Processed 545/1448 audio samples male
#  Processed 546/1448 audio samples male
#  Processed 547/1448 audio samples male
#  Processed 548/1448 audio samples male
#  Processed 549/1448 audio samples male
#  Processed 550/1448 audio samples male
#  Processed 551/1448 audio samples male
#  Processed 552/1448 audio samples male
#  Processed 553/1448 audio samples male
#  Processed 554/1448 audio samples male
#  Processed 555/1448 audio samples male
#  Processed 556/1448 audio samples male
#  Processed 557/1448 audio samples male
#  Processed 558/1448 audio samples male
#  Processed 559/1448 audio samples male
#  Processed 560/1448 audio samples male
#  Processed 561/1448 audio samples male
#  Processed 562/1448 audio samples male
#  Processed 563/1448 audio samples male
#  Processed 564/1448 audio samples male
#  Processed 565/1448 audio samples male
#  Processed 566/1448 audio samples male
#  Processed 567/1448 audio samples male
#  Processed 568/1448 audio samples male
#  Processed 569/1448 audio samples male
#  Processed 570/1448 audio samples male
#  Processed 571/1448 audio samples male
#  Processed 572/1448 audio samples male
#  Processed 573/1448 audio samples male
#  Processed 574/1448 audio samples male
#  Processed 575/1448 audio samples male
#  Processed 576/1448 audio samples male
#  Processed 577/1448 audio samples male
#  Processed 578/1448 audio samples male
#  Processed 579/1448 audio samples male
#  Processed 580/1448 audio samples male
#  Processed 581/1448 audio samples male
#  Processed 582/1448 audio samples male
#  Processed 583/1448 audio samples male
#  Processed 584/1448 audio samples male
#  Processed 585/1448 audio samples male
#  Processed 586/1448 audio samples male
#  Processed 587/1448 audio samples male
#  Processed 588/1448 audio samples male
#  Processed 589/1448 audio samples male
#  Processed 590/1448 audio samples male
#  Processed 591/1448 audio samples male
#  Processed 592/1448 audio samples male
#  Processed 593/1448 audio samples male
#  Processed 594/1448 audio samples male
#  Processed 595/1448 audio samples male
#  Processed 596/1448 audio samples male
#  Processed 597/1448 audio samples male
#  Processed 598/1448 audio samples male
#  Processed 599/1448 audio samples male
#  Processed 600/1448 audio samples male
#  Processed 601/1448 audio samples male
#  Processed 602/1448 audio samples male
#  Processed 603/1448 audio samples male
#  Processed 604/1448 audio samples male
#  Processed 605/1448 audio samples male
#  Processed 606/1448 audio samples male
#  Processed 607/1448 audio samples male
#  Processed 608/1448 audio samples male
#  Processed 609/1448 audio samples male
#  Processed 610/1448 audio samples male
#  Processed 611/1448 audio samples male
#  Processed 612/1448 audio samples male
#  Processed 613/1448 audio samples male
#  Processed 614/1448 audio samples male
#  Processed 615/1448 audio samples male
#  Processed 616/1448 audio samples male
#  Processed 617/1448 audio samples male
#  Processed 618/1448 audio samples male
#  Processed 619/1448 audio samples male
#  Processed 620/1448 audio samples male
#  Processed 621/1448 audio samples male
#  Processed 622/1448 audio samples male
#  Processed 623/1448 audio samples male
#  Processed 624/1448 audio samples male
#  Processed 625/1448 audio samples male
#  Processed 626/1448 audio samples male
#  Processed 627/1448 audio samples male
#  Processed 628/1448 audio samples male
#  Processed 629/1448 audio samples male
#  Processed 630/1448 audio samples male
#  Processed 631/1448 audio samples male
#  Processed 632/1448 audio samples male
#  Processed 633/1448 audio samples male
#  Processed 634/1448 audio samples male
#  Processed 635/1448 audio samples male
#  Processed 636/1448 audio samples male
#  Processed 637/1448 audio samples male
#  Processed 638/1448 audio samples male
#  Processed 639/1448 audio samples male
#  Processed 640/1448 audio samples male
#  Processed 641/1448 audio samples male
#  Processed 642/1448 audio samples male
#  Processed 643/1448 audio samples male
#  Processed 644/1448 audio samples male
#  Processed 645/1448 audio samples male
#  Processed 646/1448 audio samples male
#  Processed 647/1448 audio samples male
#  Processed 648/1448 audio samples male
#  Processed 649/1448 audio samples male
#  Processed 650/1448 audio samples male
#  Processed 651/1448 audio samples male
#  Processed 652/1448 audio samples male
#  Processed 653/1448 audio samples male
#  Processed 654/1448 audio samples male
#  Processed 655/1448 audio samples male
#  Processed 656/1448 audio samples male
#  Processed 657/1448 audio samples male
#  Processed 658/1448 audio samples male
#  Processed 659/1448 audio samples male
#  Processed 660/1448 audio samples female
#  Processed 661/1448 audio samples female
#  Processed 662/1448 audio samples female
#  Processed 663/1448 audio samples female
#  Processed 664/1448 audio samples female
#  Processed 665/1448 audio samples female
#  Processed 666/1448 audio samples female
#  Processed 667/1448 audio samples female
#  Processed 668/1448 audio samples female
#  Processed 669/1448 audio samples female
#  Processed 670/1448 audio samples female
#  Processed 671/1448 audio samples female
#  Processed 672/1448 audio samples female
#  Processed 673/1448 audio samples female
#  Processed 674/1448 audio samples female
#  Processed 675/1448 audio samples female
#  Processed 676/1448 audio samples female
#  Processed 677/1448 audio samples female
#  Processed 678/1448 audio samples female
#  Processed 679/1448 audio samples female
#  Processed 680/1448 audio samples female
#  Processed 681/1448 audio samples female
#  Processed 682/1448 audio samples female
#  Processed 683/1448 audio samples female
#  Processed 684/1448 audio samples female
#  Processed 685/1448 audio samples female
#  Processed 686/1448 audio samples female
#  Processed 687/1448 audio samples female
#  Processed 688/1448 audio samples female
#  Processed 689/1448 audio samples female
#  Processed 690/1448 audio samples female
#  Processed 691/1448 audio samples female
#  Processed 692/1448 audio samples female
#  Processed 693/1448 audio samples female
#  Processed 694/1448 audio samples female
#  Processed 695/1448 audio samples female
#  Processed 696/1448 audio samples female
#  Processed 697/1448 audio samples female
#  Processed 698/1448 audio samples female
#  Processed 699/1448 audio samples female
#  Processed 700/1448 audio samples female
#  Processed 701/1448 audio samples female
#  Processed 702/1448 audio samples female
#  Processed 703/1448 audio samples female
#  Processed 704/1448 audio samples female
#  Processed 705/1448 audio samples female
#  Processed 706/1448 audio samples female
#  Processed 707/1448 audio samples female
#  Processed 708/1448 audio samples female
#  Processed 709/1448 audio samples female
#  Processed 710/1448 audio samples female
#  Processed 711/1448 audio samples female
#  Processed 712/1448 audio samples female
#  Processed 713/1448 audio samples female
#  Processed 714/1448 audio samples female
#  Processed 715/1448 audio samples female
#  Processed 716/1448 audio samples female
#  Processed 717/1448 audio samples female
#  Processed 718/1448 audio samples female
#  Processed 719/1448 audio samples female
#  Processed 720/1448 audio samples female
#  Processed 721/1448 audio samples female
#  Processed 722/1448 audio samples female
#  Processed 723/1448 audio samples female
#  Processed 724/1448 audio samples female
#  Processed 725/1448 audio samples female
#  Processed 726/1448 audio samples female
#  Processed 727/1448 audio samples female
#  Processed 728/1448 audio samples female
#  Processed 729/1448 audio samples female
#  Processed 730/1448 audio samples female
#  Processed 731/1448 audio samples female
#  Processed 732/1448 audio samples female
#  Processed 733/1448 audio samples female
#  Processed 734/1448 audio samples female
#  Processed 735/1448 audio samples female
#  Processed 736/1448 audio samples female
#  Processed 737/1448 audio samples female
#  Processed 738/1448 audio samples female
#  Processed 739/1448 audio samples female
#  Processed 740/1448 audio samples female
#  Processed 741/1448 audio samples female
#  Processed 742/1448 audio samples female
#  Processed 743/1448 audio samples female
#  Processed 744/1448 audio samples female
#  Processed 745/1448 audio samples female
#  Processed 746/1448 audio samples female
#  Processed 747/1448 audio samples female
#  Processed 748/1448 audio samples female
#  Processed 749/1448 audio samples female
#  Processed 750/1448 audio samples female
#  Processed 751/1448 audio samples female
#  Processed 752/1448 audio samples female
#  Processed 753/1448 audio samples female
#  Processed 754/1448 audio samples female
#  Processed 755/1448 audio samples female
#  Processed 756/1448 audio samples female
#  Processed 757/1448 audio samples female
#  Processed 758/1448 audio samples female
#  Processed 759/1448 audio samples female
#  Processed 760/1448 audio samples female
#  Processed 761/1448 audio samples female
#  Processed 762/1448 audio samples female
#  Processed 763/1448 audio samples female
#  Processed 764/1448 audio samples female
#  Processed 765/1448 audio samples female
#  Processed 766/1448 audio samples female
#  Processed 767/1448 audio samples female
#  Processed 768/1448 audio samples female
#  Processed 769/1448 audio samples female
#  Processed 770/1448 audio samples female
#  Processed 771/1448 audio samples female
#  Processed 772/1448 audio samples female
#  Processed 773/1448 audio samples female
#  Processed 774/1448 audio samples female
#  Processed 775/1448 audio samples female
#  Processed 776/1448 audio samples female
#  Processed 777/1448 audio samples female
#  Processed 778/1448 audio samples female
#  Processed 779/1448 audio samples female
#  Processed 780/1448 audio samples female
#  Processed 781/1448 audio samples female
#  Processed 782/1448 audio samples female
#  Processed 783/1448 audio samples female
#  Processed 784/1448 audio samples female
#  Processed 785/1448 audio samples female
#  Processed 786/1448 audio samples female
#  Processed 787/1448 audio samples female
#  Processed 788/1448 audio samples female
#  Processed 789/1448 audio samples female
#  Processed 790/1448 audio samples female
#  Processed 791/1448 audio samples female
#  Processed 792/1448 audio samples female
#  Processed 793/1448 audio samples female
#  Processed 794/1448 audio samples female
#  Processed 795/1448 audio samples female
#  Processed 796/1448 audio samples female
#  Processed 797/1448 audio samples female
#  Processed 798/1448 audio samples female
#  Processed 799/1448 audio samples female
#  Processed 800/1448 audio samples female
#  Processed 801/1448 audio samples female
#  Processed 802/1448 audio samples female
#  Processed 803/1448 audio samples female
#  Processed 804/1448 audio samples female
#  Processed 805/1448 audio samples female
#  Processed 806/1448 audio samples female
#  Processed 807/1448 audio samples female
#  Processed 808/1448 audio samples female
#  Processed 809/1448 audio samples female
#  Processed 810/1448 audio samples female
#  Processed 811/1448 audio samples female
#  Processed 812/1448 audio samples female
#  Processed 813/1448 audio samples female
#  Processed 814/1448 audio samples female
#  Processed 815/1448 audio samples female
#  Processed 816/1448 audio samples female
#  Processed 817/1448 audio samples female
#  Processed 818/1448 audio samples female
#  Processed 819/1448 audio samples female
#  Processed 820/1448 audio samples female
#  Processed 821/1448 audio samples female
#  Processed 822/1448 audio samples female
#  Processed 823/1448 audio samples female
#  Processed 824/1448 audio samples female
#  Processed 825/1448 audio samples female
#  Processed 826/1448 audio samples female
#  Processed 827/1448 audio samples female
#  Processed 828/1448 audio samples female
#  Processed 829/1448 audio samples female
#  Processed 830/1448 audio samples female
#  Processed 831/1448 audio samples female
#  Processed 832/1448 audio samples female
#  Processed 833/1448 audio samples female
#  Processed 834/1448 audio samples female
#  Processed 835/1448 audio samples female
#  Processed 836/1448 audio samples female
#  Processed 837/1448 audio samples female
#  Processed 838/1448 audio samples female
#  Processed 839/1448 audio samples female
#  Processed 840/1448 audio samples male
#  Processed 841/1448 audio samples male
#  Processed 842/1448 audio samples male
#  Processed 843/1448 audio samples male
#  Processed 844/1448 audio samples male
#  Processed 845/1448 audio samples male
#  Processed 846/1448 audio samples male
#  Processed 847/1448 audio samples male
#  Processed 848/1448 audio samples male
#  Processed 849/1448 audio samples male
#  Processed 850/1448 audio samples male
#  Processed 851/1448 audio samples male
#  Processed 852/1448 audio samples male
#  Processed 853/1448 audio samples male
#  Processed 854/1448 audio samples male
#  Processed 855/1448 audio samples male
#  Processed 856/1448 audio samples male
#  Processed 857/1448 audio samples male
#  Processed 858/1448 audio samples male
#  Processed 859/1448 audio samples male
#  Processed 860/1448 audio samples male
#  Processed 861/1448 audio samples male
#  Processed 862/1448 audio samples male
#  Processed 863/1448 audio samples male
#  Processed 864/1448 audio samples male
#  Processed 865/1448 audio samples male
#  Processed 866/1448 audio samples male
#  Processed 867/1448 audio samples male
#  Processed 868/1448 audio samples male
#  Processed 869/1448 audio samples male
#  Processed 870/1448 audio samples male
#  Processed 871/1448 audio samples male
#  Processed 872/1448 audio samples male
#  Processed 873/1448 audio samples male
#  Processed 874/1448 audio samples male
#  Processed 875/1448 audio samples male
#  Processed 876/1448 audio samples male
#  Processed 877/1448 audio samples male
#  Processed 878/1448 audio samples male
#  Processed 879/1448 audio samples male
#  Processed 880/1448 audio samples male
#  Processed 881/1448 audio samples male
#  Processed 882/1448 audio samples male
#  Processed 883/1448 audio samples male
#  Processed 884/1448 audio samples male
#  Processed 885/1448 audio samples male
#  Processed 886/1448 audio samples male
#  Processed 887/1448 audio samples male
#  Processed 888/1448 audio samples male
#  Processed 889/1448 audio samples male
#  Processed 890/1448 audio samples male
#  Processed 891/1448 audio samples male
#  Processed 892/1448 audio samples male
#  Processed 893/1448 audio samples male
#  Processed 894/1448 audio samples male
#  Processed 895/1448 audio samples male
#  Processed 896/1448 audio samples male
#  Processed 897/1448 audio samples male
#  Processed 898/1448 audio samples male
#  Processed 899/1448 audio samples male
#  Processed 900/1448 audio samples female
#  Processed 901/1448 audio samples female
#  Processed 902/1448 audio samples female
#  Processed 903/1448 audio samples female
#  Processed 904/1448 audio samples female
#  Processed 905/1448 audio samples female
#  Processed 906/1448 audio samples female
#  Processed 907/1448 audio samples female
#  Processed 908/1448 audio samples female
#  Processed 909/1448 audio samples female
#  Processed 910/1448 audio samples female
#  Processed 911/1448 audio samples female
#  Processed 912/1448 audio samples female
#  Processed 913/1448 audio samples female
#  Processed 914/1448 audio samples female
#  Processed 915/1448 audio samples female
#  Processed 916/1448 audio samples female
#  Processed 917/1448 audio samples female
#  Processed 918/1448 audio samples female
#  Processed 919/1448 audio samples female
#  Processed 920/1448 audio samples female
#  Processed 921/1448 audio samples female
#  Processed 922/1448 audio samples female
#  Processed 923/1448 audio samples female
#  Processed 924/1448 audio samples female
#  Processed 925/1448 audio samples female
#  Processed 926/1448 audio samples female
#  Processed 927/1448 audio samples female
#  Processed 928/1448 audio samples female
#  Processed 929/1448 audio samples female
#  Processed 930/1448 audio samples female
#  Processed 931/1448 audio samples female
#  Processed 932/1448 audio samples female
#  Processed 933/1448 audio samples female
#  Processed 934/1448 audio samples female
#  Processed 935/1448 audio samples female
#  Processed 936/1448 audio samples female
#  Processed 937/1448 audio samples female
#  Processed 938/1448 audio samples female
#  Processed 939/1448 audio samples female
#  Processed 940/1448 audio samples female
#  Processed 941/1448 audio samples female
#  Processed 942/1448 audio samples female
#  Processed 943/1448 audio samples female
#  Processed 944/1448 audio samples female
#  Processed 945/1448 audio samples female
#  Processed 946/1448 audio samples female
#  Processed 947/1448 audio samples female
#  Processed 948/1448 audio samples female
#  Processed 949/1448 audio samples female
#  Processed 950/1448 audio samples female
#  Processed 951/1448 audio samples female
#  Processed 952/1448 audio samples female
#  Processed 953/1448 audio samples female
#  Processed 954/1448 audio samples female
#  Processed 955/1448 audio samples female
#  Processed 956/1448 audio samples female
#  Processed 957/1448 audio samples female
#  Processed 958/1448 audio samples female
#  Processed 959/1448 audio samples female
#  Processed 960/1448 audio samples male
#  Processed 961/1448 audio samples male
#  Processed 962/1448 audio samples male
#  Processed 963/1448 audio samples male
#  Processed 964/1448 audio samples male
#  Processed 965/1448 audio samples male
#  Processed 966/1448 audio samples male
#  Processed 967/1448 audio samples male
#  Processed 968/1448 audio samples male
#  Processed 969/1448 audio samples male
#  Processed 970/1448 audio samples male
#  Processed 971/1448 audio samples male
#  Processed 972/1448 audio samples male
#  Processed 973/1448 audio samples male
#  Processed 974/1448 audio samples male
#  Processed 975/1448 audio samples male
#  Processed 976/1448 audio samples male
#  Processed 977/1448 audio samples male
#  Processed 978/1448 audio samples male
#  Processed 979/1448 audio samples male
#  Processed 980/1448 audio samples male
#  Processed 981/1448 audio samples male
#  Processed 982/1448 audio samples male
#  Processed 983/1448 audio samples male
#  Processed 984/1448 audio samples male
#  Processed 985/1448 audio samples male
#  Processed 986/1448 audio samples male
#  Processed 987/1448 audio samples male
#  Processed 988/1448 audio samples male
#  Processed 989/1448 audio samples male
#  Processed 990/1448 audio samples male
#  Processed 991/1448 audio samples male
#  Processed 992/1448 audio samples male
#  Processed 993/1448 audio samples male
#  Processed 994/1448 audio samples male
#  Processed 995/1448 audio samples male
#  Processed 996/1448 audio samples male
#  Processed 997/1448 audio samples male
#  Processed 998/1448 audio samples male
#  Processed 999/1448 audio samples male
#  Processed 1000/1448 audio samples male
#  Processed 1001/1448 audio samples male
#  Processed 1002/1448 audio samples male
#  Processed 1003/1448 audio samples male
#  Processed 1004/1448 audio samples male
#  Processed 1005/1448 audio samples male
#  Processed 1006/1448 audio samples male
#  Processed 1007/1448 audio samples male
#  Processed 1008/1448 audio samples male
#  Processed 1009/1448 audio samples male
#  Processed 1010/1448 audio samples male
#  Processed 1011/1448 audio samples male
#  Processed 1012/1448 audio samples male
#  Processed 1013/1448 audio samples male
#  Processed 1014/1448 audio samples male
#  Processed 1015/1448 audio samples male
#  Processed 1016/1448 audio samples male
#  Processed 1017/1448 audio samples male
#  Processed 1018/1448 audio samples male
#  Processed 1019/1448 audio samples male
#  Processed 1020/1448 audio samples female
#  Processed 1021/1448 audio samples female
#  Processed 1022/1448 audio samples female
#  Processed 1023/1448 audio samples female
#  Processed 1024/1448 audio samples female
#  Processed 1025/1448 audio samples female
#  Processed 1026/1448 audio samples female
#  Processed 1027/1448 audio samples female
#  Processed 1028/1448 audio samples female
#  Processed 1029/1448 audio samples female
#  Processed 1030/1448 audio samples female
#  Processed 1031/1448 audio samples female
#  Processed 1032/1448 audio samples female
#  Processed 1033/1448 audio samples female
#  Processed 1034/1448 audio samples female
#  Processed 1035/1448 audio samples female
#  Processed 1036/1448 audio samples female
#  Processed 1037/1448 audio samples female
#  Processed 1038/1448 audio samples female
#  Processed 1039/1448 audio samples female
#  Processed 1040/1448 audio samples female
#  Processed 1041/1448 audio samples female
#  Processed 1042/1448 audio samples female
#  Processed 1043/1448 audio samples female
#  Processed 1044/1448 audio samples female
#  Processed 1045/1448 audio samples female
#  Processed 1046/1448 audio samples female
#  Processed 1047/1448 audio samples female
#  Processed 1048/1448 audio samples female
#  Processed 1049/1448 audio samples female
#  Processed 1050/1448 audio samples female
#  Processed 1051/1448 audio samples female
#  Processed 1052/1448 audio samples female
#  Processed 1053/1448 audio samples female
#  Processed 1054/1448 audio samples female
#  Processed 1055/1448 audio samples female
#  Processed 1056/1448 audio samples female
#  Processed 1057/1448 audio samples female
#  Processed 1058/1448 audio samples female
#  Processed 1059/1448 audio samples female
#  Processed 1060/1448 audio samples female
#  Processed 1061/1448 audio samples female
#  Processed 1062/1448 audio samples female
#  Processed 1063/1448 audio samples female
#  Processed 1064/1448 audio samples female
#  Processed 1065/1448 audio samples female
#  Processed 1066/1448 audio samples female
#  Processed 1067/1448 audio samples female
#  Processed 1068/1448 audio samples female
#  Processed 1069/1448 audio samples female
#  Processed 1070/1448 audio samples female
#  Processed 1071/1448 audio samples female
#  Processed 1072/1448 audio samples female
#  Processed 1073/1448 audio samples female
#  Processed 1074/1448 audio samples female
#  Processed 1075/1448 audio samples female
#  Processed 1076/1448 audio samples female
#  Processed 1077/1448 audio samples female
#  Processed 1078/1448 audio samples female
#  Processed 1079/1448 audio samples female
#  Processed 1080/1448 audio samples male
#  Processed 1081/1448 audio samples male
#  Processed 1082/1448 audio samples male
#  Processed 1083/1448 audio samples male
#  Processed 1084/1448 audio samples male
#  Processed 1085/1448 audio samples male
#  Processed 1086/1448 audio samples male
#  Processed 1087/1448 audio samples male
#  Processed 1088/1448 audio samples male
#  Processed 1089/1448 audio samples male
#  Processed 1090/1448 audio samples male
#  Processed 1091/1448 audio samples male
#  Processed 1092/1448 audio samples male
#  Processed 1093/1448 audio samples male
#  Processed 1094/1448 audio samples male
#  Processed 1095/1448 audio samples male
#  Processed 1096/1448 audio samples male
#  Processed 1097/1448 audio samples male
#  Processed 1098/1448 audio samples male
#  Processed 1099/1448 audio samples male
#  Processed 1100/1448 audio samples male
#  Processed 1101/1448 audio samples male
#  Processed 1102/1448 audio samples male
#  Processed 1103/1448 audio samples male
#  Processed 1104/1448 audio samples male
#  Processed 1105/1448 audio samples male
#  Processed 1106/1448 audio samples male
#  Processed 1107/1448 audio samples male
#  Processed 1108/1448 audio samples male
#  Processed 1109/1448 audio samples male
#  Processed 1110/1448 audio samples male
#  Processed 1111/1448 audio samples male
#  Processed 1112/1448 audio samples male
#  Processed 1113/1448 audio samples male
#  Processed 1114/1448 audio samples male
#  Processed 1115/1448 audio samples male
#  Processed 1116/1448 audio samples male
#  Processed 1117/1448 audio samples male
#  Processed 1118/1448 audio samples male
#  Processed 1119/1448 audio samples male
#  Processed 1120/1448 audio samples male
#  Processed 1121/1448 audio samples male
#  Processed 1122/1448 audio samples male
#  Processed 1123/1448 audio samples male
#  Processed 1124/1448 audio samples male
#  Processed 1125/1448 audio samples male
#  Processed 1126/1448 audio samples male
#  Processed 1127/1448 audio samples male
#  Processed 1128/1448 audio samples male
#  Processed 1129/1448 audio samples male
#  Processed 1130/1448 audio samples male
#  Processed 1131/1448 audio samples male
#  Processed 1132/1448 audio samples male
#  Processed 1133/1448 audio samples male
#  Processed 1134/1448 audio samples male
#  Processed 1135/1448 audio samples male
#  Processed 1136/1448 audio samples male
#  Processed 1137/1448 audio samples male
#  Processed 1138/1448 audio samples male
#  Processed 1139/1448 audio samples male
#  Processed 1140/1448 audio samples male
#  Processed 1141/1448 audio samples male
#  Processed 1142/1448 audio samples male
#  Processed 1143/1448 audio samples male
#  Processed 1144/1448 audio samples male
#  Processed 1145/1448 audio samples male
#  Processed 1146/1448 audio samples male
#  Processed 1147/1448 audio samples male
#  Processed 1148/1448 audio samples male
#  Processed 1149/1448 audio samples male
#  Processed 1150/1448 audio samples male
#  Processed 1151/1448 audio samples male
#  Processed 1152/1448 audio samples male
#  Processed 1153/1448 audio samples male
#  Processed 1154/1448 audio samples male
#  Processed 1155/1448 audio samples male
#  Processed 1156/1448 audio samples male
#  Processed 1157/1448 audio samples male
#  Processed 1158/1448 audio samples male
#  Processed 1159/1448 audio samples male
#  Processed 1160/1448 audio samples male
#  Processed 1161/1448 audio samples male
#  Processed 1162/1448 audio samples male
#  Processed 1163/1448 audio samples male
#  Processed 1164/1448 audio samples male
#  Processed 1165/1448 audio samples male
#  Processed 1166/1448 audio samples male
#  Processed 1167/1448 audio samples male
#  Processed 1168/1448 audio samples male
#  Processed 1169/1448 audio samples male
#  Processed 1170/1448 audio samples male
#  Processed 1171/1448 audio samples male
#  Processed 1172/1448 audio samples male
#  Processed 1173/1448 audio samples male
#  Processed 1174/1448 audio samples male
#  Processed 1175/1448 audio samples male
#  Processed 1176/1448 audio samples male
#  Processed 1177/1448 audio samples male
#  Processed 1178/1448 audio samples male
#  Processed 1179/1448 audio samples male
#  Processed 1180/1448 audio samples male
#  Processed 1181/1448 audio samples male
#  Processed 1182/1448 audio samples male
#  Processed 1183/1448 audio samples male
#  Processed 1184/1448 audio samples male
#  Processed 1185/1448 audio samples male
#  Processed 1186/1448 audio samples male
#  Processed 1187/1448 audio samples male
#  Processed 1188/1448 audio samples male
#  Processed 1189/1448 audio samples male
#  Processed 1190/1448 audio samples male
#  Processed 1191/1448 audio samples male
#  Processed 1192/1448 audio samples male
#  Processed 1193/1448 audio samples male
#  Processed 1194/1448 audio samples male
#  Processed 1195/1448 audio samples male
#  Processed 1196/1448 audio samples male
#  Processed 1197/1448 audio samples male
#  Processed 1198/1448 audio samples male
#  Processed 1199/1448 audio samples male
#  Processed 1200/1448 audio samples male
#  Processed 1201/1448 audio samples male
#  Processed 1202/1448 audio samples male
#  Processed 1203/1448 audio samples male
#  Processed 1204/1448 audio samples male
#  Processed 1205/1448 audio samples male
#  Processed 1206/1448 audio samples male
#  Processed 1207/1448 audio samples male
#  Processed 1208/1448 audio samples male
#  Processed 1209/1448 audio samples male
#  Processed 1210/1448 audio samples male
#  Processed 1211/1448 audio samples male
#  Processed 1212/1448 audio samples male
#  Processed 1213/1448 audio samples male
#  Processed 1214/1448 audio samples male
#  Processed 1215/1448 audio samples male
#  Processed 1216/1448 audio samples male
#  Processed 1217/1448 audio samples male
#  Processed 1218/1448 audio samples male
#  Processed 1219/1448 audio samples male
#  Processed 1220/1448 audio samples male
#  Processed 1221/1448 audio samples male
#  Processed 1222/1448 audio samples male
#  Processed 1223/1448 audio samples male
#  Processed 1224/1448 audio samples male
#  Processed 1225/1448 audio samples male
#  Processed 1226/1448 audio samples male
#  Processed 1227/1448 audio samples male
#  Processed 1228/1448 audio samples male
#  Processed 1229/1448 audio samples male
#  Processed 1230/1448 audio samples male
#  Processed 1231/1448 audio samples male
#  Processed 1232/1448 audio samples male
#  Processed 1233/1448 audio samples male
#  Processed 1234/1448 audio samples male
#  Processed 1235/1448 audio samples male
#  Processed 1236/1448 audio samples male
#  Processed 1237/1448 audio samples male
#  Processed 1238/1448 audio samples male
#  Processed 1239/1448 audio samples male
#  Processed 1240/1448 audio samples male
#  Processed 1241/1448 audio samples male
#  Processed 1242/1448 audio samples male
#  Processed 1243/1448 audio samples male
#  Processed 1244/1448 audio samples male
#  Processed 1245/1448 audio samples male
#  Processed 1246/1448 audio samples male
#  Processed 1247/1448 audio samples male
#  Processed 1248/1448 audio samples male
#  Processed 1249/1448 audio samples male
#  Processed 1250/1448 audio samples male
#  Processed 1251/1448 audio samples male
#  Processed 1252/1448 audio samples male
#  Processed 1253/1448 audio samples male
#  Processed 1254/1448 audio samples male
#  Processed 1255/1448 audio samples male
#  Processed 1256/1448 audio samples male
#  Processed 1257/1448 audio samples male
#  Processed 1258/1448 audio samples male
#  Processed 1259/1448 audio samples male
#  Processed 1260/1448 audio samples female
#  Processed 1261/1448 audio samples female
#  Processed 1262/1448 audio samples female
#  Processed 1263/1448 audio samples female
#  Processed 1264/1448 audio samples female
#  Processed 1265/1448 audio samples female
#  Processed 1266/1448 audio samples female
#  Processed 1267/1448 audio samples female
#  Processed 1268/1448 audio samples female
#  Processed 1269/1448 audio samples female
#  Processed 1270/1448 audio samples female
#  Processed 1271/1448 audio samples female
#  Processed 1272/1448 audio samples female
#  Processed 1273/1448 audio samples female
#  Processed 1274/1448 audio samples female
#  Processed 1275/1448 audio samples female
#  Processed 1276/1448 audio samples female
#  Processed 1277/1448 audio samples female
#  Processed 1278/1448 audio samples female
#  Processed 1279/1448 audio samples female
#  Processed 1280/1448 audio samples female
#  Processed 1281/1448 audio samples female
#  Processed 1282/1448 audio samples female
#  Processed 1283/1448 audio samples female
#  Processed 1284/1448 audio samples female
#  Processed 1285/1448 audio samples female
#  Processed 1286/1448 audio samples female
#  Processed 1287/1448 audio samples female
#  Processed 1288/1448 audio samples female
#  Processed 1289/1448 audio samples female
#  Processed 1290/1448 audio samples female
#  Processed 1291/1448 audio samples female
#  Processed 1292/1448 audio samples female
#  Processed 1293/1448 audio samples female
#  Processed 1294/1448 audio samples female
#  Processed 1295/1448 audio samples female
#  Processed 1296/1448 audio samples female
#  Processed 1297/1448 audio samples female
#  Processed 1298/1448 audio samples female
#  Processed 1299/1448 audio samples female
#  Processed 1300/1448 audio samples female
#  Processed 1301/1448 audio samples female
#  Processed 1302/1448 audio samples female
#  Processed 1303/1448 audio samples female
#  Processed 1304/1448 audio samples female
#  Processed 1305/1448 audio samples female
#  Processed 1306/1448 audio samples female
#  Processed 1307/1448 audio samples female
#  Processed 1308/1448 audio samples female
#  Processed 1309/1448 audio samples female
#  Processed 1310/1448 audio samples female
#  Processed 1311/1448 audio samples female
#  Processed 1312/1448 audio samples female
#  Processed 1313/1448 audio samples female
#  Processed 1314/1448 audio samples female
#  Processed 1315/1448 audio samples female
#  Processed 1316/1448 audio samples female
#  Processed 1317/1448 audio samples female
#  Processed 1318/1448 audio samples female
#  Processed 1319/1448 audio samples female
#  Processed 1320/1448 audio samples female
#  Processed 1321/1448 audio samples female
#  Processed 1322/1448 audio samples female
#  Processed 1323/1448 audio samples female
#  Processed 1324/1448 audio samples female
#  Processed 1325/1448 audio samples female
#  Processed 1326/1448 audio samples female
#  Processed 1327/1448 audio samples female
#  Processed 1328/1448 audio samples female
#  Processed 1329/1448 audio samples female
#  Processed 1330/1448 audio samples female
#  Processed 1331/1448 audio samples female
#  Processed 1332/1448 audio samples female
#  Processed 1333/1448 audio samples female
#  Processed 1334/1448 audio samples female
#  Processed 1335/1448 audio samples female
#  Processed 1336/1448 audio samples female
#  Processed 1337/1448 audio samples female
#  Processed 1338/1448 audio samples female
#  Processed 1339/1448 audio samples female
#  Processed 1340/1448 audio samples female
#  Processed 1341/1448 audio samples female
#  Processed 1342/1448 audio samples female
#  Processed 1343/1448 audio samples female
#  Processed 1344/1448 audio samples female
#  Processed 1345/1448 audio samples female
#  Processed 1346/1448 audio samples female
#  Processed 1347/1448 audio samples female
#  Processed 1348/1448 audio samples female
#  Processed 1349/1448 audio samples female
#  Processed 1350/1448 audio samples female
#  Processed 1351/1448 audio samples female
#  Processed 1352/1448 audio samples female
#  Processed 1353/1448 audio samples female
#  Processed 1354/1448 audio samples female
#  Processed 1355/1448 audio samples female
#  Processed 1356/1448 audio samples female
#  Processed 1357/1448 audio samples female
#  Processed 1358/1448 audio samples female
#  Processed 1359/1448 audio samples female
#  Processed 1360/1448 audio samples female
#  Processed 1361/1448 audio samples female
#  Processed 1362/1448 audio samples female
#  Processed 1363/1448 audio samples female
#  Processed 1364/1448 audio samples female
#  Processed 1365/1448 audio samples female
#  Processed 1366/1448 audio samples female
#  Processed 1367/1448 audio samples female
#  Processed 1368/1448 audio samples female
#  Processed 1369/1448 audio samples female
#  Processed 1370/1448 audio samples female
#  Processed 1371/1448 audio samples female
#  Processed 1372/1448 audio samples female
#  Processed 1373/1448 audio samples female
#  Processed 1374/1448 audio samples female
#  Processed 1375/1448 audio samples female
#  Processed 1376/1448 audio samples female
#  Processed 1377/1448 audio samples female
#  Processed 1378/1448 audio samples female
#  Processed 1379/1448 audio samples female
#  Processed 1380/1448 audio samples male
#  Processed 1381/1448 audio samples male
#  Processed 1382/1448 audio samples male
#  Processed 1383/1448 audio samples male
#  Processed 1384/1448 audio samples male
#  Processed 1385/1448 audio samples male
#  Processed 1386/1448 audio samples male
#  Processed 1387/1448 audio samples male
#  Processed 1388/1448 audio samples male
#  Processed 1389/1448 audio samples male
#  Processed 1390/1448 audio samples male
#  Processed 1391/1448 audio samples male
#  Processed 1392/1448 audio samples male
#  Processed 1393/1448 audio samples male
#  Processed 1394/1448 audio samples male
#  Processed 1395/1448 audio samples male
#  Processed 1396/1448 audio samples male
#  Processed 1397/1448 audio samples male
#  Processed 1398/1448 audio samples male
#  Processed 1399/1448 audio samples male
#  Processed 1400/1448 audio samples male
#  Processed 1401/1448 audio samples male
#  Processed 1402/1448 audio samples male
#  Processed 1403/1448 audio samples male
#  Processed 1404/1448 audio samples male
#  Processed 1405/1448 audio samples male
#  Processed 1406/1448 audio samples male
#  Processed 1407/1448 audio samples male
#  Processed 1408/1448 audio samples male
#  Processed 1409/1448 audio samples male
#  Processed 1410/1448 audio samples male
#  Processed 1411/1448 audio samples male
#  Processed 1412/1448 audio samples male
#  Processed 1413/1448 audio samples male
#  Processed 1414/1448 audio samples male
#  Processed 1415/1448 audio samples male
#  Processed 1416/1448 audio samples male
#  Processed 1417/1448 audio samples male
#  Processed 1418/1448 audio samples male
#  Processed 1419/1448 audio samples male
#  Processed 1420/1448 audio samples male
#  Processed 1421/1448 audio samples male
#  Processed 1422/1448 audio samples male
#  Processed 1423/1448 audio samples male
#  Processed 1424/1448 audio samples male
#  Processed 1425/1448 audio samples male
#  Processed 1426/1448 audio samples male
#  Processed 1427/1448 audio samples male
#  Processed 1428/1448 audio samples male
#  Processed 1429/1448 audio samples male
#  Processed 1430/1448 audio samples male
#  Processed 1431/1448 audio samples male
#  Processed 1432/1448 audio samples male
#  Processed 1433/1448 audio samples male
#  Processed 1434/1448 audio samples male
#  Processed 1435/1448 audio samples male
#  Processed 1436/1448 audio samples male
#  Processed 1437/1448 audio samples male
#  Processed 1438/1448 audio samples male
#  Processed 1439/1448 audio samples male
#  Processed 1440/1448 audio samples male
#  Processed 1441/1448 audio samples female
#  Processed 1442/1448 audio samples female
#  Processed 1443/1448 audio samples female
#  Processed 1444/1448 audio samples female
#  Processed 1445/1448 audio samples female
#  Processed 1446/1448 audio samples female
#  Processed 1447/1448 audio samples female
#  Processed 1448/1448 audio samples female

# %% [markdown]
# Let's now see the class balance of our dataset, it is important to have a balanced dataset for ML models.

# %%
# plot emotions
plt.figure(figsize=(35,4))
plt.subplot(1,3,1)
#np.unique returns ordered list of unique elements and count of each element
emotion_list, count = np.unique(emotions, return_counts=True)
plt.bar(x=range(8), height=count)
plt.xticks(ticks=range(8), labels = [emotion for emotion in emotion_list],fontsize=10)
plt.xlabel('Emotion')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()

# plot the gender the same way as emotions
plt.figure(figsize=(35,8))
plt.subplot(1,3,1)
gender_list, count = np.unique(features, return_counts=True)
plt.bar(x=range(2), height=count)
plt.xticks(ticks=range(2), labels = [gender for gender in gender_list],fontsize=10)
plt.xlabel('Gender')
plt.tick_params(labelsize=16)
plt.ylabel('Number of Samples')
plt.show()

# %% [markdown]
# **Great, the classes appear to be balanced. That makes the task easier.** All emotions _except_ the neutral class have a "strong" intensity so there are half as many neutral samples. That might have an impact.
#
# We will continue working on this dataset in the upcoming weeks, so save your work!
